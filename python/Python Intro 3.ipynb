# %% [markdown]
# # Python Intro - Part 3

# %% [markdown]
# # Working with Pandas Data Frames

# %%
import pandas as pd
 
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
## add new colums to the df
iris['sepal_ratio'] = iris.sepal_length / iris.sepal_width
iris.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species  \
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa
#
#    sepal_ratio
# 0     1.457143
# 1     1.633333
# 2     1.468750
# 3     1.483871
# 4     1.388889

# %%
iris['petal_ratio'] = iris.petal_length / iris['petal_width']
iris.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species  \
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa
#
#    sepal_ratio  petal_ratio
# 0     1.457143          7.0
# 1     1.633333          7.0
# 2     1.468750          6.5
# 3     1.483871          7.5
# 4     1.388889          7.0

# %%
## now proceed with checking the values of the df
iris.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
#
#        sepal_ratio  petal_ratio
# count   150.000000   150.000000
# mean      1.953681     4.310500
# std       0.400480     2.489648
# min       1.268293     2.125000
# 25%       1.546188     2.802381
# 50%       2.032292     3.300000
# 75%       2.224910     4.666667
# max       2.961538    15.000000

# %%
## create categorical variables for the sepal and petal width
iris['petalw_cat'] = pd.np.floor(iris.petal_width)
iris['sepalw_cat'] = pd.np.floor(iris.sepal_width)
iris.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
#
#        sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# count   150.000000   150.000000  150.000000  150.000000
# mean      1.953681     4.310500    0.860000    2.646667
# std       0.400480     2.489648    0.714472    0.532648
# min       1.268293     2.125000    0.000000    2.000000
# ...

# %%
## subsetting
iris[iris.petalw_cat==2]
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 100         101           6.3          3.3           6.0          2.5
# 102         103           7.1          3.0           5.9          2.1
# 104         105           6.5          3.0           5.8          2.2
# 105         106           7.6          3.0           6.6          2.1
# 109         110           7.2          3.6           6.1          2.5
# 110         111           6.5          3.2           5.1          2.0
# 112         113           6.8          3.0           5.5          2.1
# 113         114           5.7          2.5           5.0          2.0
# 114         115           5.8          2.8           5.1          2.4
# 115         116           6.4          3.2           5.3          2.3
# 117         118           7.7          3.8           6.7          2.2
# 118         119           7.7          2.6           6.9          2.3
# ...

# %%
iris.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
#
#        sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# count   150.000000   150.000000  150.000000  150.000000
# mean      1.953681     4.310500    0.860000    2.646667
# std       0.400480     2.489648    0.714472    0.532648
# min       1.268293     2.125000    0.000000    2.000000
# ...

# %%
### subsetting for given values
iris[iris.species.isin(['virginica','versicolor'])]
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 50           51           7.0          3.2           4.7          1.4
# 51           52           6.4          3.2           4.5          1.5
# 52           53           6.9          3.1           4.9          1.5
# 53           54           5.5          2.3           4.0          1.3
# 54           55           6.5          2.8           4.6          1.5
# 55           56           5.7          2.8           4.5          1.3
# 56           57           6.3          3.3           4.7          1.6
# 57           58           4.9          2.4           3.3          1.0
# 58           59           6.6          2.9           4.6          1.3
# 59           60           5.2          2.7           3.9          1.4
# 60           61           5.0          2.0           3.5          1.0
# 61           62           5.9          3.0           4.2          1.5
# ...

# %%
# subsetting between values

iris2 = iris.copy()
iris2 = iris2[iris2['petal_length'].between(5,6)]
iris2.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count   37.000000     37.000000    37.000000     37.000000    37.000000
# mean   124.513514      6.454054     2.954054      5.432432     2.016216
# std     18.703270      0.395527     0.280470      0.318899     0.297689
# min     78.000000      5.700000     2.200000      5.000000     1.400000
# 25%    112.000000      6.300000     2.800000      5.100000     1.800000
# 50%    126.000000      6.400000     3.000000      5.500000     2.000000
# 75%    141.000000      6.700000     3.200000      5.700000     2.300000
# max    150.000000      7.200000     3.400000      6.000000     2.500000
#
#        sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# count    37.000000    37.000000   37.000000   37.000000
# mean      2.198928     2.749890    1.567568    2.621622
# std       0.193236     0.426338    0.502247    0.491672
# min       1.823529     2.125000    1.000000    2.000000
# ...

# %%
iris.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
#
#        sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# count   150.000000   150.000000  150.000000  150.000000
# mean      1.953681     4.310500    0.860000    2.646667
# std       0.400480     2.489648    0.714472    0.532648
# min       1.268293     2.125000    0.000000    2.000000
# ...

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
### aggregate - added to pandas version 0.20.0 !!!
iris.agg({'petal_ratio':[min,max,"mean","median",len],'sepal_ratio':[min,max,"mean","median",len]})
# Out:
#         petal_ratio  sepal_ratio
# min          2.1250     1.268293
# max         15.0000     2.961538
# mean         4.3105     1.953681
# median       3.3000     2.032292
# len        150.0000   150.000000

# %%
iris.groupby('species').agg({'sepal_length':[min,max,len]})
# Out:
#            sepal_length
#                     min  max   len
# species
# setosa              4.3  5.8  50.0
# versicolor          4.9  7.0  50.0
# virginica           4.9  7.9  50.0

# %% [markdown]
#  iris %>% filter() %>% group_by() %>% summarise()

# %%
### getting all together (like with dplyr in R)
# 1. filter
# 2. group
# 3. summarise
iris[(iris.sepalw_cat.isin([0,2,3])) & (iris['petal_length'].between(1,4))].\
    groupby('species').\
    agg({'sepal_ratio':[min,"mean","median",max,len], 'petal_ratio':[min,"mean","median",max,len]})
# Out:
#            sepal_ratio                                     petal_ratio  \
#                    min      mean    median       max   len         min
# species
# setosa        1.277778  1.482307  1.468750  1.956522  46.0    2.666667
# versicolor    1.925926  2.219015  2.196154  2.727273  16.0    2.727273
#
#
#                 mean median   max   len
# species
# setosa      6.818478    7.0  15.0  46.0
# versicolor  3.274770    3.3   4.0  16.0

# %% [markdown]
# # Working with Files (I/O)
#
# #### Read, write and append data

# %%
f = open("iris.csv",'r')
### read the first line
f.readline()
# Out:
# '"","sepal_length","sepal_width","petal_length","petal_width","species"\n'

# %%
### read the next line
f.readline()
# Out:
# '"1",5.1,3.5,1.4,0.2,"setosa"\n'

# %%
### read the next line
f.readline()
# Out:
# '"2",4.9,3,1.4,0.2,"setosa"\n'

# %%
### read the next lines after the actual cursor
f.readlines()
# Out:
# ['"1",5.1,3.5,1.4,0.2,"setosa"\n',
#  '"2",4.9,3,1.4,0.2,"setosa"\n',
#  '"3",4.7,3.2,1.3,0.2,"setosa"\n',
#  '"4",4.6,3.1,1.5,0.2,"setosa"\n',
#  '"5",5,3.6,1.4,0.2,"setosa"\n',
#  '"6",5.4,3.9,1.7,0.4,"setosa"\n',
#  '"7",4.6,3.4,1.4,0.3,"setosa"\n',
#  '"8",5,3.4,1.5,0.2,"setosa"\n',
#  '"9",4.4,2.9,1.4,0.2,"setosa"\n',
#  '"10",4.9,3.1,1.5,0.1,"setosa"\n',
#  '"11",5.4,3.7,1.5,0.2,"setosa"\n',
#  '"12",4.8,3.4,1.6,0.2,"setosa"\n',
#  '"13",4.8,3,1.4,0.1,"setosa"\n',
#  '"14",4.3,3,1.1,0.1,"setosa"\n',
#  '"15",5.8,4,1.2,0.2,"setosa"\n',
#  '"16",5.7,4.4,1.5,0.4,"setosa"\n',
#  '"17",5.4,3.9,1.3,0.4,"setosa"\n',
#  '"18",5.1,3.5,1.4,0.3,"setosa"\n',
#  '"19",5.7,3.8,1.7,0.3,"setosa"\n',
#  '"20",5.1,3.8,1.5,0.3,"setosa"\n',
#  '"21",5.4,3.4,1.7,0.2,"setosa"\n',
#  '"22",5.1,3.7,1.5,0.4,"setosa"\n',
#  '"23",4.6,3.6,1,0.2,"setosa"\n',
#  '"24",5.1,3.3,1.7,0.5,"setosa"\n',
#  '"25",4.8,3.4,1.9,0.2,"setosa"\n',
#  '"26",5,3,1.6,0.2,"setosa"\n',
#  '"27",5,3.4,1.6,0.4,"setosa"\n',
# ...

# %% [markdown]
# We can interact through the lines of the file and make some operations.
# Lets divide the dataset into three independent datasets: one for each type of flower.
#
# We will:
# - Opend the files for read/write/append
# - Iterate though lines
# - Check the content of the line for the name of the flower
# - Append the new data to the respective file
# - Close the files

# %%
### input file
f = open("iris.csv",'r')

# %%
### output file
setosa = open("setosa.csv","a")
versicolor = open("versicolor.csv","a")
virginica = open("virginica.csv","a")

# %%
### read the first line that has the column names
names = f.readline()
print(names)
# Out:
# "","sepal_length","sepal_width","petal_length","petal_width","species"

# %%
### write the column names into each of the three files
setosa.write(names)
versicolor.write(names)
virginica.write(names)
# Out:
# 71

# %%
iris = f.readlines()
for line in iris:
    if "setosa" in line:
        print("Setosa is in %s" % line)
        setosa.write(line)
    elif "versicolor" in line:
        print("Versicolor is in %s" % line)
        versicolor.write(line)
    else:
        print("Virginica is in %s" % line)
        virginica.write(line)
# Out:
# Setosa is in "1",5.1,3.5,1.4,0.2,"setosa"
#
# Setosa is in "2",4.9,3,1.4,0.2,"setosa"
#
# Setosa is in "3",4.7,3.2,1.3,0.2,"setosa"
#
# Setosa is in "4",4.6,3.1,1.5,0.2,"setosa"
#
# Setosa is in "5",5,3.6,1.4,0.2,"setosa"
#
# Setosa is in "6",5.4,3.9,1.7,0.4,"setosa"
#
# Setosa is in "7",4.6,3.4,1.4,0.3,"setosa"
#
# Setosa is in "8",5,3.4,1.5,0.2,"setosa"
#
# Setosa is in "9",4.4,2.9,1.4,0.2,"setosa"
#
# Setosa is in "10",4.9,3.1,1.5,0.1,"setosa"
#
# Setosa is in "11",5.4,3.7,1.5,0.2,"setosa"
#
# Setosa is in "12",4.8,3.4,1.6,0.2,"setosa"
#
# Setosa is in "13",4.8,3,1.4,0.1,"setosa"
#
# Setosa is in "14",4.3,3,1.1,0.1,"setosa"
#
# Setosa is in "15",5.8,4,1.2,0.2,"setosa"
#
# Setosa is in "16",5.7,4.4,1.5,0.4,"setosa"
#
# Setosa is in "17",5.4,3.9,1.3,0.4,"setosa"
#
# Setosa is in "18",5.1,3.5,1.4,0.3,"setosa"
#
# Setosa is in "19",5.7,3.8,1.7,0.3,"setosa"
#
# Setosa is in "20",5.1,3.8,1.5,0.3,"setosa"
#
# Setosa is in "21",5.4,3.4,1.7,0.2,"setosa"
#
# ...

# %%
### close the connection of the files
setosa.close()
versicolor.close()
virginica.close()

# %% [markdown]
# Another way to read the content of a file is as follows:

# %%
with open('iris.csv','r') as f:
    data = f.read()
    
data
# Out:
# '"","sepal_length","sepal_width","petal_length","petal_width","species"\n"1",5.1,3.5,1.4,0.2,"setosa"\n"2",4.9,3,1.4,0.2,"setosa"\n"3",4.7,3.2,1.3,0.2,"setosa"\n"4",4.6,3.1,1.5,0.2,"setosa"\n"5",5,3.6,1.4,0.2,"setosa"\n"6",5.4,3.9,1.7,0.4,"setosa"\n"7",4.6,3.4,1.4,0.3,"setosa"\n"8",5,3.4,1.5,0.2,"setosa"\n"9",4.4,2.9,1.4,0.2,"setosa"\n"10",4.9,3.1,1.5,0.1,"setosa"\n"11",5.4,3.7,1.5,0.2,"setosa"\n"12",4.8,3.4,1.6,0.2,"setosa"\n"13",4.8,3,1.4,0.1,"setosa"\n"14",4.3,3,1.1,0.1,"setosa"\n"15",5.8,4,1.2,0.2,"setosa"\n"16",5.7,4.4,1.5,0.4,"setosa"\n"17",5.4,3.9,1.3,0.4,"setosa"\n"18",5.1,3.5,1.4,0.3,"setosa"\n"19",5.7,3.8,1.7,0.3,"setosa"\n"20",5.1,3.8,1.5,0.3,"setosa"\n"21",5.4,3.4,1.7,0.2,"setosa"\n"22",5.1,3.7,1.5,0.4,"setosa"\n"23",4.6,3.6,1,0.2,"setosa"\n"24",5.1,3.3,1.7,0.5,"setosa"\n"25",4.8,3.4,1.9,0.2,"setosa"\n"26",5,3,1.6,0.2,"setosa"\n"27",5,3.4,1.6,0.4,"setosa"\n"28",5.2,3.5,1.5,0.2,"setosa"\n"29",5.2,3.4,1.4,0.2,"setosa"\n"30",4.7,3.2,1.6,0.2,"setosa"\n"31",4.8,3.1,1.6,0.2,"se
# ...

# %%
data.split('\n')
# Out:
# ['"","sepal_length","sepal_width","petal_length","petal_width","species"',
#  '"1",5.1,3.5,1.4,0.2,"setosa"',
#  '"2",4.9,3,1.4,0.2,"setosa"',
#  '"3",4.7,3.2,1.3,0.2,"setosa"',
#  '"4",4.6,3.1,1.5,0.2,"setosa"',
#  '"5",5,3.6,1.4,0.2,"setosa"',
#  '"6",5.4,3.9,1.7,0.4,"setosa"',
#  '"7",4.6,3.4,1.4,0.3,"setosa"',
#  '"8",5,3.4,1.5,0.2,"setosa"',
#  '"9",4.4,2.9,1.4,0.2,"setosa"',
#  '"10",4.9,3.1,1.5,0.1,"setosa"',
#  '"11",5.4,3.7,1.5,0.2,"setosa"',
#  '"12",4.8,3.4,1.6,0.2,"setosa"',
#  '"13",4.8,3,1.4,0.1,"setosa"',
#  '"14",4.3,3,1.1,0.1,"setosa"',
#  '"15",5.8,4,1.2,0.2,"setosa"',
#  '"16",5.7,4.4,1.5,0.4,"setosa"',
#  '"17",5.4,3.9,1.3,0.4,"setosa"',
#  '"18",5.1,3.5,1.4,0.3,"setosa"',
#  '"19",5.7,3.8,1.7,0.3,"setosa"',
#  '"20",5.1,3.8,1.5,0.3,"setosa"',
#  '"21",5.4,3.4,1.7,0.2,"setosa"',
#  '"22",5.1,3.7,1.5,0.4,"setosa"',
#  '"23",4.6,3.6,1,0.2,"setosa"',
#  '"24",5.1,3.3,1.7,0.5,"setosa"',
#  '"25",4.8,3.4,1.9,0.2,"setosa"',
#  '"26",5,3,1.6,0.2,"setosa"',
# ...

# %% [markdown]
# # DataBase connections
#
# ## ODBC

# %%
import pyodbc 
cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=GUYPC\SQLEXPRESS;"
                      "Database=COLLEGE;"
                      "Trusted_Connection=yes;")

# %%
cursor = cnxn.cursor()
cursor.execute('SELECT * FROM Departments$ WHERE DepartmentId is not null')

for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = (1.0, 'English')
# row = (2.0, 'Science')
# row = (3.0, 'Arts')
# row = (4.0, 'Sport')

# %%
cursor = cnxn.cursor()
cursor.execute('SELECT * FROM Teachers$ WHERE TeacherId is not null')

for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = (1.0, ' Kaylea', 'Monzingo', 'F')
# row = (2.0, ' Amanda', 'Dworkin', 'F')
# row = (3.0, ' Jordyn', 'Baron', 'F')
# row = (4.0, ' Katherine', 'Dibari', 'F')
# row = (5.0, ' Heather', 'Metcalf', 'F')
# row = (6.0, ' Madison', 'Batan', 'F')
# row = (7.0, ' Cortnee', 'Kinderknecht', 'F')
# row = (8.0, ' Caroline', 'Knuesel', 'F')
# row = (9.0, ' Katerina', 'Young', 'F')
# row = (10.0, ' Mackenzie', 'Olsen', 'F')
# row = (11.0, ' Kaitlin', 'Delude', 'F')
# row = (12.0, ' Mikayla', 'Russell', 'F')
# row = (13.0, ' Alexander', 'Watts', 'M')
# row = (14.0, ' Jeffrey', 'Batzel', 'M')
# row = (15.0, ' Conor', 'Mckittrick', 'M')
# row = (16.0, ' Robert', 'Aivazian', 'M')
# row = (17.0, ' Tanner', 'Fitzsimons', 'M')
# row = (18.0, ' Daniel', 'Bland', 'M')
# row = (19.0, ' Terran', 'Beaty', 'M')
# row = (20.0, ' Zachary', 'Healy', 'M')
# row = (21.0, ' Ernest', 'Stoyanov', 'M')
# row = (22.0, ' Darick', 'Hess', 'M')
# row = (23.0, ' Maxwell', 'Romkee', 'M')
# ...

# %%
cursor = cnxn.cursor()
cursor.execute('SELECT * FROM Students$ WHERE StudentId is not null')

for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = (162.0, ' Elmira', 'Holston', 'F')
# row = (154.0, ' Sierra', 'Van Vorst', 'F')
# row = (28.0, ' Mycah', 'Bingham', 'F')
# row = (54.0, ' Alia', 'Jones', 'F')
# row = (31.0, ' Chanda', 'Fillmore', 'F')
# row = (272.0, ' Jennifer', 'Smith', 'F')
# row = (266.0, ' Maria', 'Gaddis', 'F')
# row = (259.0, ' Taiahbeth', 'Gerard', 'F')
# row = (101.0, ' Dakota', 'Iiams', 'F')
# row = (171.0, ' Emma', 'Gellatly', 'F')
# row = (94.0, ' Cydney', 'Petersen', 'F')
# row = (210.0, ' Breanna', 'Lightcap', 'F')
# row = (76.0, ' Caitlyn', 'Austin', 'F')
# row = (92.0, ' Jenny', 'Vanmeter', 'F')
# row = (80.0, ' Mckenna', 'Yoswa', 'F')
# row = (265.0, ' Hannah', 'Anttila', 'F')
# row = (105.0, ' Hannah', 'Wilkes', 'F')
# row = (196.0, ' Rebecca', 'Bruch', 'F')
# row = (177.0, ' Tamara', 'Webber', 'F')
# row = (141.0, ' Marissa', 'Karsten', 'F')
# row = (124.0, ' Shawna', 'East', 'F')
# row = (197.0, ' Abbey', 'Singley', 'F')
# row = (121.0, ' Corine', 'Hitch', 'F')
# ...

# %%
cursor = cnxn.cursor()
cursor.execute('SELECT * FROM Courses$ WHERE CourseId is not null')

for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = (1.0, 'English Begginers', 1.0, 15.0)
# row = (2.0, 'Advanced English', 1.0, 15.0)
# row = (3.0, 'Proffesional English', 1.0, 15.0)
# row = (4.0, 'Mathematics 101', 2.0, 2.0)
# row = (5.0, 'Matematics Advanced', 2.0, 13.0)
# row = (6.0, 'Algebra', 2.0, 13.0)
# row = (7.0, 'Geometry', 2.0, 13.0)
# row = (8.0, 'Chemistry', 2.0, 14.0)
# row = (9.0, 'Physics', 2.0, 13.0)
# row = (10.0, 'Biology', 2.0, 3.0)
# row = (11.0, 'Genetics', 2.0, 19.0)
# row = (12.0, 'Neurobiology', 2.0, 19.0)
# row = (13.0, 'Statistics', 2.0, 5.0)
# row = (14.0, 'Computer Science', 2.0, 1.0)
# row = (15.0, 'Data Science', 2.0, 10.0)
# row = (16.0, 'SQL', 2.0, 20.0)
# row = (17.0, 'Python', 2.0, 19.0)
# row = (18.0, 'R', 2.0, 17.0)
# row = (19.0, 'Java', 2.0, 22.0)
# row = (20.0, 'History of Arts', 3.0, 8.0)
# row = (21.0, 'Painting', 3.0, 9.0)
# row = (22.0, 'Sculpture', 3.0, 16.0)
# row = (23.0, 'Musicology', 3.0, 6.0)
# row = (24.0, 'Theater', 3.0, 21.0)
# row = (25.0, 'Literature', 3.0, 18.0)
# ...

# %%
cursor = cnxn.cursor()
cursor.execute('SELECT * FROM Classrooms$ WHERE StudentId is not null')

for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = (1.0, 202.0, 92.03107017152607)
# row = (1.0, 12.0, 81.17591618963378)
# row = (1.0, 232.0, 82.39658665795811)
# row = (1.0, 123.0, 62.42044865624285)
# row = (1.0, 274.0, 72.56990008071197)
# row = (1.0, 150.0, 79.51124054883148)
# row = (1.0, 161.0, 65.43802491984569)
# row = (1.0, 39.0, 100.0)
# row = (1.0, 251.0, 80.60335163594269)
# row = (1.0, 30.0, 75.84617140547718)
# row = (1.0, 191.0, 66.91044898275148)
# row = (1.0, 253.0, 93.97991805342329)
# row = (1.0, 235.0, 77.25631352449273)
# row = (1.0, 46.0, 70.25909827202763)
# row = (1.0, 4.0, 70.92980072873775)
# row = (1.0, 151.0, 82.74855357274458)
# row = (1.0, 187.0, 84.39656535874278)
# row = (1.0, 18.0, 82.55218071810954)
# row = (1.0, 3.0, 83.97224533147684)
# row = (1.0, 157.0, 64.48953720216306)
# row = (1.0, 42.0, 72.04824317912905)
# row = (1.0, 231.0, 81.60827434780589)
# row = (1.0, 107.0, 73.63925522152304)
# row = (1.0, 69.0, 99.01451540117729)
# row = (1.0, 104.0, 74.03952370884738)
# ...

# %%
# get the list one by one
cursor.execute("SELECT * FROM Teachers;") 
row = cursor.fetchone() 
while row: 
    print(row )
    row = cursor.fetchone()
# Out:
# (1, 'Kaylea', 'Monzingo', 'F')
# (2, 'Amanda', 'Dworkin', 'F')
# (3, 'Jordyn', 'Baron', 'F')
# (4, 'Katherine', 'Dibari', 'F')
# (5, 'Heather', 'Metcalf', 'F')
# (6, 'Madison', 'Batan', 'F')
# (7, 'Cortnee', 'Kinderknecht', 'F')
# (8, 'Caroline', 'Knuesel', 'F')
# (9, 'Katerina', 'Young', 'F')
# (10, 'Mackenzie', 'Olsen', 'F')
# (11, 'Kaitlin', 'Delude', 'F')
# (12, 'Mikayla', 'Russell', 'F')
# (13, 'Alexander', 'Watts', 'M')
# (14, 'Jeffrey', 'Batzel', 'M')
# (15, 'Conor', 'Mckittrick', 'M')
# (16, 'Robert', 'Aivazian', 'M')
# (17, 'Tanner', 'Fitzsimons', 'M')
# (18, 'Daniel', 'Bland', 'M')
# (19, 'Terran', 'Beaty', 'M')
# (20, 'Zachary', 'Healy', 'M')
# (21, 'Ernest', 'Stoyanov', 'M')
# (22, 'Darick', 'Hess', 'M')
# (23, 'Maxwell', 'Romkee', 'M')
# (24, 'Keegan', 'Price', 'M')

# %%
### get the first 5 records
cursor.execute("SELECT * FROM Courses;") 
row = cursor.fetchmany(5) 
print(row)
# Out:
# [(1, 'English Begginers', 1, 15), (2, 'Advanced English', 1, 15), (3, 'Proffesional English', 1, 15), (4, 'Mathematics 101', 2, 2), (5, 'Matematics Advanced', 2, 13)]

# %%
### get all records
cursor.execute("SELECT * FROM Courses;") 
row = cursor.fetchall() 

print(row)
# Out:
# [(1, 'English Begginers', 1, 15), (2, 'Advanced English', 1, 15), (3, 'Proffesional English', 1, 15), (4, 'Mathematics 101', 2, 2), (5, 'Matematics Advanced', 2, 13), (6, 'Algebra', 2, 13), (7, 'Geometry', 2, 13), (8, 'Chemistry', 2, 14), (9, 'Physics', 2, 13), (10, 'Biology', 2, 3), (11, 'Genetics', 2, 19), (12, 'Neurobiology', 2, 19), (13, 'Statistics', 2, 5), (14, 'Computer Science', 2, 1), (15, 'Data Science', 2, 10), (16, 'SQL', 2, 20), (17, 'Python', 2, 19), (18, 'R', 2, 17), (19, 'Java', 2, 22), (20, 'History of Arts', 3, 8), (21, 'Painting', 3, 9), (22, 'Sculpture', 3, 16), (23, 'Musicology', 3, 6), (24, 'Theater', 3, 21), (25, 'Literature', 3, 18), (26, 'Basketball', 4, 4), (27, 'Volleyball', 4, 11), (28, 'Football', 4, 7), (29, 'Tenis', 4, 24), (30, 'Swimming', 4, 12), (31, 'Gymnastics', 4, 23)]

# %% [markdown]
# #### Pass a SQL Table to a Pandas DataFrame

# %%
import pandas as pd
import pyodbc 

cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=WIN10\TCDS;"
                      "Database=COLLEGE;"
                      "Trusted_Connection=yes;")

df = pd.read_sql("SELECT * FROM Courses",cnxn)
df.head()
# Out:
#    CourseId            CourseName  DepartmentID  TeacherId
# 0         1     English Begginers             1         15
# 1         2      Advanced English             1         15
# 2         3  Proffesional English             1         15
# 3         4       Mathematics 101             2          2
# 4         5   Matematics Advanced             2         13

# %% [markdown]
# ## SQLite3

# %%
import sqlite3
conn = sqlite3.connect("tcds_example.db")
c = conn.cursor()

# %%
c.execute('''CREATE TABLE Proglangs (
             LangId INT,
             LangName VARCHAR(50),
             IsObjectOriented INT);''')

# %%
c.execute("INSERT INTO Proglangs VALUES (1,'Perl',1);")
c.execute("INSERT INTO Proglangs VALUES (2,'C',0);")
c.execute("INSERT INTO Proglangs VALUES (3,'Basic',0);")
c.execute("INSERT INTO Proglangs VALUES (4,'C++',1);")
c.execute("INSERT INTO Proglangs VALUES (5,'Java',1);")
c.execute("INSERT INTO Proglangs VALUES (6,'Python',1);")
c.execute("INSERT INTO Proglangs VALUES (7,'Rubi',1);")
c.execute("INSERT INTO Proglangs VALUES (8,'Pascal',0);")
c.execute("INSERT INTO Proglangs VALUES (9,'Fortrant',0);")
c.execute("INSERT INTO Proglangs VALUES (10,'Scheme',0);")
c.execute("INSERT INTO Proglangs VALUES (11,'Haskell',0);")
c.execute("INSERT INTO Proglangs VALUES (12,'PHP',1);")

# %%
c.execute("SELECT * FROM Proglangs")

# %%
### get the first row
print(c.fetchone())
# Out:
# (1, 'Perl', 1)

# %%
### get the next row
print(c.fetchone())
# Out:
# (2, 'C', 0)

# %%
### get the next row
print(c.fetchone())
# Out:
# (3, 'Basic', 0)

# %%
## get all the data in the table beginind from the cursor (cursor is now on the fourth row!)
print(c.fetchall())
# Out:
# [(4, 'C++', 1), (5, 'Java', 1), (6, 'Python', 1), (7, 'Rubi', 1), (8, 'Pascal', 0), (9, 'Fortrant', 0), (10, 'Scheme', 0), (11, 'Haskell', 0), (12, 'PHP', 1)]

# %%
### print the rows obtined from a specific query
for row in c.execute("SELECT * FROM Proglangs WHERE IsObjectOriented = 1"):
    print(row)
# Out:
# (1, 'Perl', 1)
# (4, 'C++', 1)
# (5, 'Java', 1)
# (6, 'Python', 1)
# (7, 'Rubi', 1)
# (12, 'PHP', 1)

# %% [markdown]
# # Regular Expressions in Python
#
#
#
# <img src="https://i.pinimg.com/originals/19/44/b1/1944b14175b0136b578287c0169a5c69.png" width='318' height='450' style='float: left;'></img>

# %%
import re

# %%
str = '''
Name: Mr. Peter Johns
eMail: peter@gmail.com
Phone: (54)-333-25-22

Name: Mrs. Mary Green
eMail: mary@yahoo.com
Phone: (50)-231-00-19

Name: Mr. George Brown
eMail: gbrn@bbb.com
Phone: (49)-882-55-51
'''

# %%
#str='abc@example.com'
match=re.search(r'\w+@\w+.\w+',str) #return abc@example.com

match
# Out:
# <_sre.SRE_Match object; span=(30, 45), match='peter@gmail.com'>

# %%
#num='555-555-5555'
match_num=re.search(r'(\W\d{2}\W.\d{3}.\d{2}.\d{2})',str) 
match_num
# Out:
# <_sre.SRE_Match object; span=(53, 67), match='(54)-333-25-22'>

# %%
### Print eMails
pattern = re.compile(r'\w+@\w+.\w+')
matches = pattern.finditer(str)

matches

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(30, 45), match='peter@gmail.com'>
# <_sre.SRE_Match object; span=(98, 112), match='mary@yahoo.com'>
# <_sre.SRE_Match object; span=(166, 178), match='gbrn@bbb.com'>

# %%
### Print phone numbers
pattern = re.compile(r'(\W\d{2}\W.\d{3}.\d{2}.\d{2})')
matches = pattern.finditer(str)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(53, 67), match='(54)-333-25-22'>
# <_sre.SRE_Match object; span=(120, 134), match='(50)-231-00-19'>
# <_sre.SRE_Match object; span=(186, 200), match='(49)-882-55-51'>

# %%
### Print the names of the males (Mr.) in the list
### The ? sign indicates that the point is optional
pattern = re.compile(r'Mr\.?\s[A-Z]\w*\s[A-Z]\w*')
matches = pattern.finditer(str)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(7, 22), match='Mr. Peter Johns'>
# <_sre.SRE_Match object; span=(142, 158), match='Mr. George Brown'>

# %%
### Print the names of the males (Mr.) in the list
### Print phone numbers
pattern = re.compile(r'(Mr|Mrs)\.?\s[A-Z]\w*\s[A-Z]\w*')
matches = pattern.finditer(str)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(7, 22), match='Mr. Peter Johns'>
# <_sre.SRE_Match object; span=(75, 90), match='Mrs. Mary Green'>
# <_sre.SRE_Match object; span=(142, 158), match='Mr. George Brown'>

# %%
urls = '''
http://www.mysite.com
https://google.com/search?q=regular+expression+in+python
https://mail.google.com/
http://rstudio.somesite.org:8787/
http://yahoo.com
'''

# %%
pattern = re.compile(r'https?://(\w+.)?\w+.(com|org)')
matches = pattern.finditer(urls)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(1, 22), match='http://www.mysite.com'>
# <_sre.SRE_Match object; span=(23, 41), match='https://google.com'>
# <_sre.SRE_Match object; span=(80, 103), match='https://mail.google.com'>
# <_sre.SRE_Match object; span=(105, 132), match='http://rstudio.somesite.org'>
# <_sre.SRE_Match object; span=(139, 155), match='http://yahoo.com'>

# %% [markdown]
# # Virtual environments (pipenv)
# #### Why virtual environments
# #### How to create a virtual environment
# #### Using and sharing VE
#
# <a href="https://dev.to/rosejcday/do-you-use-docker-or-virtualenv-for-python---3de4"> virtenv/pipenv </a>
#
# #### Packrat (R)

# %% [markdown]
# ---
#
#
# http://www.markbetz.net/2014/01/17/python-if-you-have-docker-do-you-need-virtualenv/
#
# # Containers (Docker)
# #### What is a virtual container?
# #### Differences between VE and containers
# #### How to generate a virutual container
# #### How to enter a container
# #### Sharing containers
#
# Ubuntu docker image:
# https://github.com/tianon/docker-brew-ubuntu-core/tree/59aa7dfef17153ecc812adbf26516675ce67e8aa/bionic
#
# https://hub.docker.com/explore/
#
# ---
# # More resources on Dockers
#
# Using Linux dev environment inside Windows10 (no virtual machine needed!)
# https://nickjanetakis.com/blog/using-wsl-and-mobaxterm-to-create-a-linux-dev-environment-on-windows
#
# Dockers for data science
# https://www.analyticsvidhya.com/blog/2017/11/reproducible-data-science-docker-for-data-science/
#
# https://github.com/sachinruk/deepschool.io/
#
# https://www.kdnuggets.com/2018/01/docker-data-science.html
