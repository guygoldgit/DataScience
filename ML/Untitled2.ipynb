# %%
library(dplyr)
library(xts)
library(TTR)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
#
#
# Attaching package: ‘xts’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, last

# %%
df = read.csv("../data/Daily_Demand_Forecasting_Orders.csv",sep=";")
head(df)
dim(df)
# Out:
#   Week.of.the.month..first.week..second..third..fourth.or.fifth.week
# 1 1
# 2 1
# 3 1
# 4 2
# 5 2
# 6 2
#   Day.of.the.week..Monday.to.Friday. Non.urgent.order Urgent.order Order.type.A
# 1 4                                  316.307          223.270      61.543
# 2 5                                  128.633           96.042      38.058
# 3 6                                   43.651           84.375      21.826
# 4 2                                  171.297          127.667      41.542
# 5 3                                   90.532          113.526      37.679
# 6 4                                  110.925           96.360      30.792
#   Order.type.B Order.type.C Fiscal.sector.orders
# 1 175.586      302.448       0.000
# 2  56.037      130.580       0.000
# 3  25.125       82.461       1.386
# 4 113.294      162.284      18.156
# 5  56.618      116.220       6.459
# 6  50.704      125.868      79.000
#   Orders.from.the.traffic.controller.sector Banking.orders..1.
# ...

# %%
str(df)
# Out:
# 'data.frame':	60 obs. of  13 variables:
#  $ Week.of.the.month..first.week..second..third..fourth.or.fifth.week: int  1 1 1 2 2 2 2 2 3 3 ...
#  $ Day.of.the.week..Monday.to.Friday.                                : int  4 5 6 2 3 4 5 6 2 3 ...
#  $ Non.urgent.order                                                  : num  316.3 128.6 43.7 171.3 90.5 ...
#  $ Urgent.order                                                      : num  223.3 96 84.4 127.7 113.5 ...
#  $ Order.type.A                                                      : num  61.5 38.1 21.8 41.5 37.7 ...
#  $ Order.type.B                                                      : num  175.6 56 25.1 113.3 56.6 ...
#  $ Order.type.C                                                      : num  302.4 130.6 82.5 162.3 116.2 ...
#  $ Fiscal.sector.orders                                              : num  0 0 1.39 18.16 6.46 ...
# ...

# %%
orders <- df[,c(1,2,13)]
names(orders) <- c('week','weekday','total')

# %%
head(orders)
# Out:
#   week weekday total
# 1 1    4       539.577
# 2 1    5       224.675
# 3 1    6       129.412
# 4 2    2       317.120
# 5 2    3       210.517
# 6 2    4       207.364

# %%
order.ts <- ts(orders$total,start=1,end=60,frequency=5)
head(order.ts)
# Out:
# [1] 539.577 224.675 129.412 317.120 210.517 207.364

# %%
stats::lag(order.ts,3)

# %%
plot(order.ts)
# Out:
# plot without title

# %%
## moving average of 5 consecutive days, represent by the red line at the next code
ma5 <- TTR::SMA(order.ts,n=5)

# %%
options(repr.plot.width=8,repr.plot.height=3)
plot(order.ts)
lines(ma5,col='red')
# Out:
# plot without title

# %%
options(repr.plot.width=12,repr.plot.height=8)
stationary_dts <- decompose(order.ts)
plot(stationary_dts)
# Out:
# plot without title

# %%
as.vector(stationary_dts$seasonal)[3:62]
# Out:
#  [1] -19.004986  44.988957 -19.611289   5.657766 -12.030448 -19.004986
#  [7]  44.988957 -19.611289   5.657766 -12.030448 -19.004986  44.988957
# [13] -19.611289   5.657766 -12.030448 -19.004986  44.988957 -19.611289
# [19]   5.657766 -12.030448 -19.004986  44.988957 -19.611289   5.657766
# [25] -12.030448 -19.004986  44.988957 -19.611289   5.657766 -12.030448
# [31] -19.004986  44.988957 -19.611289   5.657766 -12.030448 -19.004986
# [37]  44.988957 -19.611289   5.657766 -12.030448 -19.004986  44.988957
# [43] -19.611289   5.657766 -12.030448 -19.004986  44.988957 -19.611289
# [49]   5.657766 -12.030448 -19.004986  44.988957 -19.611289   5.657766
# [55] -12.030448 -19.004986  44.988957 -19.611289   5.657766 -12.030448

# %%
matrix(stationary_dts$seasonal,ncol=5,byrow=T)
# Out:
# Warning message in matrix(stationary_dts$seasonal, ncol = 5, byrow = T):
# “data length [296] is not a sub-multiple or multiple of the number of rows [60]”
#       [,1]     [,2]       [,3]      [,4]      [,5]
#  [1,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [2,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [3,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [4,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [5,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [6,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [7,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [8,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
#  [9,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
# [10,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
# [11,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
# [12,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
# [13,] 5.657766 -12.030448 -19.00499  44.98896 -19.61129
# ...

# %%
season1 <- data.frame(weekday=c(4,5,6,2,3),
                     season=stationary_dts$seasonal[1:5])
season1
# Out:
#   weekday season
# 1 4         5.657766
# 2 5       -12.030448
# 3 6       -19.004986
# 4 2        44.988957
# 5 3       -19.611289

# %%
orders2 <- left_join(orders,season1,by='weekday')

# %%
orders2
# Out:
#    week weekday total   season
# 1  1    4       539.577   5.657766
# 2  1    5       224.675 -12.030448
# 3  1    6       129.412 -19.004986
# 4  2    2       317.120  44.988957
# 5  2    3       210.517 -19.611289
# 6  2    4       207.364   5.657766
# 7  2    5       263.043 -12.030448
# 8  2    6       248.958 -19.004986
# 9  3    2       344.291  44.988957
# 10 3    3       248.428 -19.611289
# 11 3    4       281.420   5.657766
# 12 3    5       243.568 -12.030448
# 13 3    6       308.178 -19.004986
# 14 4    2       363.402  44.988957
# 15 4    3       336.872 -19.611289
# 16 4    4       246.992   5.657766
# 17 4    5       308.880 -12.030448
# 18 4    6       233.126 -19.004986
# 19 5    2       404.380  44.988957
# 20 1    3       298.560 -19.611289
# 21 1    4       229.249   5.657766
# 22 1    5       236.304 -12.030448
# 23 1    6       297.174 -19.004986
# 24 2    2       409.401  44.988957
# 25 2    3       231.035 -19.611289
# 26 2    4       238.826   5.657766
# ...

# %%
library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
# Registered S3 methods overwritten by 'forecast':
#   method             from
#   fitted.fracdiff    fracdiff
#   residuals.fracdiff fracdiff

# %%
dts_fit <- auto.arima(order.ts)
dts_fit
# Out:
# Series: order.ts
# ARIMA(1,0,0)(1,0,0)[5] with non-zero mean
#
# Coefficients:
#          ar1    sar1      mean
#       0.0789  0.0912  300.7418
# s.e.  0.0588  0.0592    6.1510
#
# sigma^2 estimated as 7955:  log likelihood=-1747.8
# AIC=3503.6   AICc=3503.73   BIC=3518.36

# %%
pred <- forecast(dts_fit)

# %%
plot(pred)
# Out:
# Plot with title “Forecasts from ARIMA(1,0,0)(1,0,0)[5] with non-zero mean”
